# %%
#library
from tkinter import *
import getpass
from tkinter import ttk

#data
host_list = ['karan']
lib_user = ['karan','raman']
lib_pass = ['1234','4321']
lib_phone = [9053348568,8448945842]
user_amount = [100,1200]
lib_book = {
    'hindi':500,
    'english':450,
    'maths':200,
    'physics':100,
    'coding':600
    }
req_dict = {}
book_date = {}
book_ret = {}
pay_succ = {}


def recharge():

	def rech_cn():

		if int(rech_id.get()) in lib_phone:
			rech_ind = lib_phone.index(int(rech_id.get()))
			if rech_pass.get()==lib_pass[rech_ind]:
				user_amount[rech_ind] = user_amount[rech_ind]+int(add_rech_amt.get())
				rwin1.destroy()
			else:
				Label(rwin1,width=20, text='Incorrect password',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,columnspan=2)
				rech_pass.delete(0, END)
		else:
			Label(rwin1,width=20, text='Incorrect mobile no.',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,columnspan=2)
			rech_id.delete(0, END)




	rwin1 = Tk()
	rwin1.title("New user")
	rwin1.geometry('350x190')
	rwin1.configure(bg = '#FFFF00')

	Label(rwin1, text='Enter your mobile no.',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,column = 0,sticky='w')		
	Label(rwin1, text='Enter your password  ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 2,column = 0,sticky='w')
	Label(rwin1, text='How much INR add in wallet  ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 3,column = 0)

	
	rech_id = Entry(rwin1, width=15,bg = '#98FF98',borderwidth = 3)
	rech_id.grid(row =1 , column = 1)

	rech_pass = Entry(rwin1, show='#', width=15,bg = '#98FF98',borderwidth = 3)
	rech_pass.grid(row =2 , column = 1)

	add_rech_amt = Entry(rwin1, width=15,bg = '#98FF98',borderwidth = 3)
	add_rech_amt.grid(row =3 , column = 1)

	Button(rwin1,width=10, text = 'RECHARGE',bg = '#00FFFF',borderwidth = 5,command=rech_cn).place(x = 120, y = 140)

def lib_login():

	def submit():

		def submit_book():

			def exit():
				win8.destroy()
				loginew()

			def submit_date():

				def ctn():
					win9.destroy()
					loginew()

				current_date = current_date1.get()

				win8.destroy()
				win9 = Tk()
				win9.title('Submit book')
				win9.configure(bg = '#FFFF00')
				win9.geometry('250x140')


				
				c_day = int(current_date[-2:])
				c_month = int(current_date[-5:-3])
				c_year = int(current_date[:4])
				user_amount[lib_ind] = user_amount[lib_ind]+(lib_book[pay_succ[str(user_id)]]/2)
				if (((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))>30 and 35>(((c_day)+((c_month)*30))-((t_day)+((t_month)*30))):
					((c_day)+((c_month)*30))-((t_day)+((t_month)*30))
					# print(f'{20*((((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))-30)}% fine is applied  ')
					Label(win9, text=f'{20*((((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))-30)}% fine is applied',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0, columnspan=2)
					for x in range((((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))-30):
						user_amount[lib_ind] = (user_amount[lib_ind])-(lib_book[pay_succ[str(user_id)]]/5)
				elif (((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))>35:
					user_amount[lib_ind] = (user_amount[lib_ind])-(lib_book[pay_succ[str(user_id)]])
					# print("100% fine applied for late submission ")
					Label(win9, text='100\% fine applied for late submission',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1, columnspan=2)
				
				book_ret.update({str(user_id):pay_succ[str(user_id)]})
				pay_succ.pop(str(user_id))
				book_date.pop(str(user_id))
				print((((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))<35)
				if ((((c_day)+((c_month)*30))-((t_day)+((t_month)*30)))<35)==True:
					print('okk')
					Label(win9, text='Your payment refunded sucessfully ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 2)


				Label(win9, text=f'Available balance is {user_amount[lib_ind]}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 3, columnspan=2)

				Button(win9, borderwidth = 5, text = 'Continue',bg = '#00FFFF',command=ctn).place(x = 110, y = 100)



			try:
				win4.destroy()
			except:
				win3.destroy()

			win8 = Tk()
			win8.title("Submit book")
			win8.configure(bg = '#FFFF00')
			
			if str(user_id) in pay_succ:
				print('hii')
				win8.geometry('320x150')
				
				Label(win8, text=f"Date of taking book is {book_date[str(user_id)]}",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,columnspan=2)
				taken_date = book_date[str(user_id)]
				t_day = int(taken_date[-2:])
				t_month = int(taken_date[-5:-3])
				t_year = int(taken_date[0:4])
				Label(win8, text="Enter current date (year-month-date):",bg = '#FFFF00').grid(row = 2,column = 0)
				current_date1 = Entry(win8, width=15,bg = '#98FF98',borderwidth = 3)
				current_date1.grid(row = 2, column = 1)
				Button(win8, borderwidth = 5, text = 'Submit',bg = '#00FFFF',command=submit_date).place(x = 130, y = 110)

			else:

				win8.geometry('180x90')
				Label(win8, text=' ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,column=0)
				Label(win8, text='No book given to you',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,column=1)
				Button(win8,width=8, borderwidth = 5, text = 'Exit',bg = '#00FFFF',command=exit).place(x = 50, y = 40)
				

		def get_book():

			def srch_book():

				

				def cancel():
					win5.destroy()
					get_book()

				def sub_req():
					req_dict.update({user_id:book})
					win5.destroy()
					loginew()

				def pay():

					def ctn2():
						win6.destroy()
						get_book()

					def pay_pass():

						def cnt():
							win7.destroy()
							loginew()

						

						if password.get()==lib_pass[lib_ind]:
							user_amount[lib_ind] = (user_amount[lib_ind])-(lib_book[book]/2)
							from datetime import date
							today = date.today()
							str_today =str(today)

							win6.destroy()
							win7 = Tk()
							win7.title('Payment successful')
							win7.configure(bg = '#FFFF00')
							win7.geometry('475x200')

							Label(win7, text=f'Payment successful, {str_today}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0)
							book_date.update({str(user_id):str_today})
							pay_succ.update({str(user_id):book})
							Label(win7, text=f"Now available balance in your wallet is {user_amount[lib_ind]}",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1)
							Label(win7, text="Note: if you are not submit your book in 30 days 20\% charge per day will be fine is applied",bg = '#FFFF00',font = ('Comic Sans MS',8)).grid(row = 2)
							Button(win7,width = 10, borderwidth = 5, text = 'Continue',bg = '#00FFFF',command = cnt).place(x = 190, y = 120)
							# 	lib_bank[0] = lib_bank[0]+(lib_book[book]/2)

						else:
							Label(win6, text='Incorrect password !!',bg = '#FFFF00').grid(row = 2, column = 1)
							password.delete(0, END)



					win5.destroy()
					win6 = Tk()
					win6.title('Pay')
					win6.configure(bg = '#FFFF00')
					win6.geometry('320x150')

					Label(win6, text=f"Available balance in your wallet is {user_amount[lib_ind]}",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0, columnspan = 2)

					if lib_book[book]<user_amount[lib_ind]:
						Label(win6, text="Password :",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1, column = 0)
						password = Entry(win6,show='#', width = 15, borderwidth = 5, bg = '#98FF98')
						password.grid(row = 1, column = 1)
						Button(win6,width = 12, borderwidth = 5, text = 'Submit',bg = '#00FFFF',command = pay_pass).place(x =167, y = 85)

					else:
						Label(win6, text='Not enough balance to get book',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1, column = 0)
						Button(win6,width = 12, borderwidth = 5, text = 'RECHARGE',bg = '#00FFFF',command = recharge).place(x =60, y = 85)
						Button(win6,width = 12, borderwidth = 5, text = 'Back',bg = '#00FFFF',command = ctn2).place(x =180, y = 85)



				book = book_name.get()
				win4.destroy()
				win5 = Tk()
				win5.title('Payment')
				win5.geometry('305x190') 
				win5.configure(bg = '#FFFF00')


				def cancel():
					win5.destroy()
					loginew()

				if book in lib_book:

					Label(win5, text=f'Price of {book} book is {lib_book[book]}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0)
					Label(win5, text = f"You need to give {lib_book[book]/2} INR for security",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1)
					Label(win5, text ="Go for payment ",bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 2)
					Button(win5,width = 10, borderwidth = 5, text = 'Pay',bg = '#00FFFF',command = pay).place(x =50, y = 110)
					Button(win5,width = 10, borderwidth = 5, text = 'Cancel',bg = '#00FFFF',command= cancel).place(x = 160, y =110)

				else:
					Label(win5, text=f'Sorry, {book} isn\'t available',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0)
					Label(win5, text='Do you want to put request for this book ?',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1)

					Button(win5,width = 10, borderwidth = 5, text = 'Submit',bg = '#00FFFF', command= sub_req).place(x =50, y = 80)
					Button(win5,width = 10, borderwidth = 5, text = 'Cancel',bg = '#00FFFF',command= cancel).place(x =160, y = 80)

			def exit():
				win4.destroy()
				loginew()

			if str(user_id) in pay_succ:

				global win4

				win3.destroy()
				win4 = Tk()
				win4.title('Library-Books')
				win4.geometry('230x130')
				win4.configure(bg = '#FFFF00')

				Label(win4, text = f'First submit the {pay_succ[str(user_id)]} book', font = ('Comic Sans MS',12),bg = '#FFFF00').grid(row = 0)
				Label(win4, text = 'Then try to take another book', font = ('Comic Sans MS',12),bg = '#FFFF00').grid(row = 1)

				Button(win4, text = 'Submit book', command= submit_book, bg = '#00FFFF').place(x= 30, y = 80)
				Button(win4, text = 'Exit',width=10 ,command= exit, bg = '#00FFFF').place(x= 140, y = 80)





			else:
				
				try:
					win3.destroy()
				except:
					pass

				win4 = Tk()
				win4.title('Library-Books')
				win4.geometry('250x300')
				win4.configure(bg = '#FFFF00')

				Label(win4,bg ='#FFFF00' ).grid(row=0)
				Label(win4,bg ='#FFFF00' ).grid(row=1)
				

				Label(win4, text= 'Required book',bg = '#FFFF00',font = ('Comic Sans MS',8)).place(x = 2, y=3)
				book_name = Entry(win4, width=15,bg = '#98FF98',borderwidth = 3)
				book_name.place(x=85, y = 2)
				Button(win4, text = 'Select', command= srch_book, bg = '#00FFFF').place(x= 190, y = 4 , height = 18)

				Label(win4, text = " ", font = ('Comic Sans MS',12),bg = '#FFFF00').grid(row = 2, column =0)
				Label(win4, text = "These books are available", font = ('Comic Sans MS',12),bg = '#FFFF00').grid(row = 2, columnspan =2,column=1)
				Label(win4, text = 'Name', width = 15, borderwidth = 2, relief = RAISED,bg = '#00FF00').grid(row = 3, column = 1)
				Label(win4, text = 'Price', width = 15, borderwidth = 2, relief = RAISED,bg = '#00FF00').grid(row = 3, column = 2)

				x = 4
				for name, price in lib_book.items():
					Label(win4, width = 15,relief = GROOVE,borderwidth = 2,	text = f'{name.capitalize()}',bg = '#ADD8E6').grid(row = x, column = 1)
					Label(win4, width = 15,relief = GROOVE,borderwidth = 2, text = f'{price}',bg = '#ADD8E6').grid(row = x, column = 2)
					x += 1


		

		def cancel():
			win3.destroy()
			loginew()

		if int(user_id1.get()) in lib_phone:
			user_id = int(user_id1.get())
			lib_ind = lib_phone.index(user_id)
			win2.destroy()
			win3 = Tk()
			win3.title('Library')
			win3.geometry('250x140')
			win3.configure(bg = '#FFFF00')

			Label(win3, text = f'Hello {lib_user[lib_ind].capitalize()}, welcome to Library', font = ('Comic Sans MS',10),bg = '#FFFF00').place(x = 33, y = 10 )

			Button(win3,width = 12, text = 'Get book', command = get_book, bg= '#00FFFF').place(x = 30 , y= 50)
			Button(win3,width = 12, text = 'Submit book', command = submit_book, bg = '#00FFFF').place(x = 140 , y= 50)
			Button(win3,width = 12, text = 'RECHARGE', command = recharge, bg = '#00FFFF').place(x = 80 , y= 90)

		else:
			win2.destroy()
			win3 = Tk()
			win3.title('Library')
			win3.geometry('280x100')
			win3.configure(bg = '#FFFF00')
			Label(win3,	text = 'Mobile no. not registered !!',bg = '#FFFF00',font = ('Comic Sans MS',12)).place(x = 30, y = 10)

			Button(win3,width = 15, text = 'Create account', command = cancel, bg = '#00FFFF').place( x= 20, y = 50)
			Button(win3,width = 12, text = 'Exit', command = cancel, bg = '#00FFFF').place( x= 160, y = 50)


	win.destroy()
	win2 = Tk()
	win2.title('login')
	win2.geometry('215x120')
	win2.configure(bg = '#FFFF00')

	Label(win2, text = 'Enter registered mobile no.', font = ('Comic Sans MS',10),bg = '#FFFF00',).place(x = 20, y =10 )
	global user_id1
	user_id1 = Entry(win2, width = 30, borderwidth = 5,bg = '#98FF98')
	user_id1.place(x = 10, y = 40)

	Button(win2,width=12, text= 'Submit', command = submit,bg = '#00FFFF').place(x = 65, y = 80)

def host():

	def submit():

		def payments():
			hwin3 = Tk()
			hwin3.title('Payments')
			hwin3.configure(bg = '#FFFF00')
			Label(hwin3,width=15,borderwidth=3,relief=RAISED, text='Mobile no.',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky='w')
			Label(hwin3,width=15,borderwidth=3,relief=RAISED, text='Book name',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 1,sticky='w')
			pay_count = 1
			for x, y in pay_succ.items():
				Label(hwin3,relief = GROOVE,width=15,borderwidth = 2, text=f'{x}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = pay_count,column = 0,)
				Label(hwin3,relief = GROOVE,width=15,borderwidth = 2, text=f'{y.capitalize()}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = pay_count,column = 1,)
				pay_count += 1
			if len(pay_succ)==0:
				Label(hwin3, text='No payments made rencently',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,columnspan = 2)

		def requests():
			hwin4 = Tk()
			hwin4.title('Requests')
			hwin4.configure(bg = '#FFFF00')
			Label(hwin4,width=15,borderwidth=3,relief=RAISED, text='Mobile no.',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky='w')
			Label(hwin4,width=15,borderwidth=3,relief=RAISED, text='Book name',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 1,sticky='w')
			req_count = 1
			for x, y in req_dict.items():
				Label(hwin4,relief = GROOVE,borderwidth = 2,width=15, text=f'{x}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = req_count,column = 0,)
				Label(hwin4,relief = GROOVE,borderwidth = 2,width=15, text=f'{y.capitalize()}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = req_count,column = 1)
				req_count += 1
			if len(req_dict)==0:
				Label(hwin4, text='No requests made rencently',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,columnspan = 2)

		def returns():
			hwin5 = Tk()
			hwin5.title('Returns')
			hwin5.configure(bg = '#FFFF00')
			Label(hwin5,width=15,borderwidth=3,relief=RAISED, text='Mobile no.',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky='w')
			Label(hwin5,width=15,borderwidth=3,relief=RAISED, text='Book name',bg = '#00FF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 1,sticky='w')
			ret_count = 1
			for x, y in book_ret.items():
				Label(hwin5,relief = GROOVE,borderwidth = 2,width=15, text=f'{x}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = ret_count,column = 0,)
				Label(hwin5,relief = GROOVE,borderwidth = 2,width=15, text=f'{y.capitalize()}',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = ret_count,column = 1)
				ret_count += 1
			if len(req_dict)==0:
				Label(hwin5, text='No returns made rencently',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,columnspan = 2)

		def add_book():

			def add_new_book():
				lib_book.update({add_book_name.get():int(add_book_price.get())})
				hwin6.destroy()

			hwin6 = Tk()
			hwin6.title('Returns')
			hwin6.configure(bg = '#FFFF00')
			hwin6.geometry('290x130')


			Label(hwin6, text='Enter book name',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky = 'w')
			Label(hwin6, text='Enter book price  ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,column = 0)		

			add_book_name = Entry(hwin6, width=15,bg = '#98FF98',borderwidth = 3)
			add_book_name.grid(row =0 , column = 1)	

			add_book_price = Entry(hwin6, width=15,bg = '#98FF98',borderwidth = 3)
			add_book_price.grid(row =1 , column = 1)

			Button(hwin6,width=10, text = 'Add',bg = '#00FFFF',borderwidth = 5,command= add_new_book).place(x = 100, y = 80)                    

		def rem_book():

			def rem_old_book():
				if rem_book_name.get() in lib_book:
					lib_book.pop(rem_book_name.get())

				hwin7.destroy()

			hwin7 = Tk()
			hwin7.title('Returns')
			hwin7.configure(bg = '#FFFF00')
			hwin7.geometry('280x80')

			
			Label(hwin7, text='Enter book name         ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky = 'w')
			rem_book_name = Entry(hwin7, width=15,bg = '#98FF98',borderwidth = 3)
			rem_book_name.grid(row =0 , column = 1)	

			Button(hwin7,width=10, text = 'Remove',bg = '#00FFFF',borderwidth = 5,command= rem_old_book).place(x = 100, y = 50)


		def exit():
			hwin2.destroy()
			loginew()

		#host
		if host_name.get() in host_list:
			Label(hwin1,width=14, text='    ',bg = '#FFFF00').grid(row = 1,column = 1)
			if host_pass.get()=='mylib':
				hwin1.destroy()
				hwin2 = Tk()
				hwin2.title('Host')
				hwin2.configure(bg = '#FFFF00')
				hwin2.geometry('300x90')

				Button(hwin2,width=10, text = 'Payments',bg = '#00FFFF',borderwidth = 5,command=payments).place(x = 10, y = 10)
				Button(hwin2,width=10, text = 'Requests',bg = '#00FFFF',borderwidth= 5,command=requests).place(x = 110, y = 10)
				Button(hwin2,width=10, text = 'Returns',bg = '#00FFFF', borderwidth = 5,command=returns).place(x = 210, y = 10)
				Button(hwin2,width=10, text = 'Add book',bg = '#00FFFF',borderwidth = 5,command=add_book).place(x = 10, y = 50)
				Button(hwin2,width=10, text = 'Remove book',bg = '#00FFFF',borderwidth= 5,command=rem_book).place(x = 110, y = 50)
				Button(hwin2,width=10, text = 'Exit',bg = '#00FFFF', borderwidth = 5,command=exit).place(x = 210, y = 50)

			else:
				Label(hwin1, text='Incorrect password',bg = '#FFFF00').grid(row = 3,column = 1)
				host_pass.delete(0, END)

		else:
			Label(hwin1, text='ID not registered!',bg = '#FFFF00').grid(row = 1,column = 1)
			host_name.delete(0, END)


	win.destroy()
	hwin1 = Tk()
	hwin1.title('Host-login')
	hwin1.configure(bg = '#FFFF00')
	hwin1.geometry('290x130')

	Label(hwin1, text='Enter host name',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky = 'w')
	Label(hwin1, text='Enter host password      ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 2,column = 0)

	host_name = Entry(hwin1, width=15,bg = '#98FF98',borderwidth = 3)
	host_name.grid(row =0 , column = 1)

	host_pass = Entry(hwin1,show='#', width=15,bg = '#98FF98',borderwidth = 3)
	host_pass.grid(row =2, column=1)

	Button(hwin1,width=10, text = 'Submit',bg = '#00FFFF',borderwidth = 5,command= submit).place(x = 90, y = 80)

def new_lib():

	def cancel():
		nwin1.destroy()
		loginew()

	def add_new_user():
		
		lib_user.append(add_name.get())
		lib_pass.append(add_pass.get())
		lib_phone.append(int(add_mn.get()))
		user_amount.append(int(add_amt.get()))
		nwin1.destroy()
		loginew()

	win.destroy()
	nwin1 = Tk()
	nwin1.title("New user")
	nwin1.geometry('340x190')
	nwin1.configure(bg = '#FFFF00')


	Label(nwin1, text='Enter your name',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 0,column = 0,sticky = 'w')
	Label(nwin1, text='Enter your mobile no.',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 1,column = 0,sticky='w')		
	Label(nwin1, text='Enter your new password  ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 2,column = 0,sticky='w')
	Label(nwin1, text='How much INR add in wallet  ',bg = '#FFFF00',font = ('Comic Sans MS',12)).grid(row = 3,column = 0)

	add_name = Entry(nwin1, width=15,bg = '#98FF98',borderwidth = 3)
	add_name.grid(row =0 , column = 1)

	add_mn = Entry(nwin1, width=15,bg = '#98FF98',borderwidth = 3)
	add_mn.grid(row =1 , column = 1)

	add_pass = Entry(nwin1, width=15,bg = '#98FF98',borderwidth = 3)
	add_pass.grid(row =2 , column = 1)

	add_amt = Entry(nwin1, width=15,bg = '#98FF98',borderwidth = 3)
	add_amt.grid(row =3 , column = 1)

	Button(nwin1,width=10, text = 'Add',bg = '#00FFFF',borderwidth = 5,command= add_new_user).place(x = 60, y = 140)
	Button(nwin1,width=10, text = 'Cancel',bg = '#00FFFF',borderwidth = 5,command= cancel).place(x = 200, y = 140)

def loginew():

    global win
    win = Tk()
    win.title("Library")
    win.geometry('300x50')
    win.configure(bg = '#FFFF00')

    Button(win,width=10, text = 'New user',bg = '#00FFFF',borderwidth = 5, command=new_lib).place(x = 10, y = 10)
    Button(win,width=10, text = 'Login',bg = '#00FFFF',borderwidth= 5, command = lib_login).place(x = 110, y = 10)
    Button(win,width=10, text = 'Host',bg = '#00FFFF', borderwidth = 5, command = host).place(x = 210, y = 10)

    win.mainloop()

loginew()
